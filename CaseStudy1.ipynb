# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(-1, 784)
x_test  = x_test.reshape(-1, 784)

x_train = x_train / 255.0
x_test  = x_test / 255.0

print("Training data shape:", x_train.shape)
print("Testing data shape:", x_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Training data shape: (60000, 784)
# Testing data shape: (10000, 784)

# %%
model = Sequential([
    Dense(128, activation='relu', input_shape=(784,)), 
    Dense(10, activation='softmax')                    
])
# Out:
# c:\Users\palak\anaconda3\envs\dl_env\lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    x_train, y_train,
    epochs=10,
    batch_size=32,
    validation_split=0.1
)
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - accuracy: 0.9220 - loss: 0.2733 - val_accuracy: 0.9673 - val_loss: 0.1200
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9650 - loss: 0.1182 - val_accuracy: 0.9767 - val_loss: 0.0870
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.9751 - loss: 0.0816 - val_accuracy: 0.9778 - val_loss: 0.0803
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.9823 - loss: 0.0598 - val_accuracy: 0.9792 - val_loss: 0.0726
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9856 - loss: 0.0467 - val_accuracy: 0.9790 - val_loss: 0.0792
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9886 - loss: 0.0360 - val_accuracy: 0.9780 - val_loss: 0.0819
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9907 - loss: 0.0292 - val_accuracy: 0.9795 - val_loss: 0.0722
# Epoch 8/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9925 - loss: 0.0236 - val_accuracy: 0.9797 - val_loss: 0.0819
# Epoch 9/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9939 - loss: 0.0194 - val_accuracy: 0.9785 - val_loss: 0.0801
# Epoch 10/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.9947 - loss: 0.0163 - val_accuracy: 0.9777 - val_loss: 0.0860

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test Loss:", test_loss)
print("Test Accuracy:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9782 - loss: 0.0820
# Test Loss: 0.08203455805778503
# Test Accuracy: 0.9782000184059143

# %%
plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Training', 'Validation'])
plt.title('Training vs Validation Accuracy')
plt.show()

# %%
plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training', 'Validation'])
plt.title('Training vs Validation Loss')
plt.show()

# %%
plt.figure()
plt.plot(history.history['loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss vs Epochs')
plt.show()
